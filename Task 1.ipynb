# %% [markdown]
# <a href="https://colab.research.google.com/github/Sruthi-Mohan/Project-/blob/main/Task%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn import linear_model

# %%
df=pd.read_csv("/content/drive/MyDrive/Share dataset.csv")
print("Load the data")
df
# Out:
# Load the data
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Hours'].plot(kind='hist', bins=20, title='Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Scores'].plot(kind='hist', bins=20, title='Scores')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Hours', y='Scores', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Hours'].plot(kind='line', figsize=(8, 4), title='Hours')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Scores'].plot(kind='line', figsize=(8, 4), title='Scores')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.shape
# Out:
# (25, 2)

# %%
df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Hours'].plot(kind='hist', bins=20, title='Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Scores'].plot(kind='hist', bins=20, title='Scores')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Hours', y='Scores', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Hours'].plot(kind='line', figsize=(8, 4), title='Hours')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Scores'].plot(kind='line', figsize=(8, 4), title='Scores')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.groupby(['Hours'])['Scores'].mean()
# Out:
# Hours
# 1.1    17.0
# 1.5    20.0
# 1.9    24.0
# 2.5    25.5
# 2.7    27.5
# 3.2    27.0
# 3.3    42.0
# 3.5    30.0
# 3.8    35.0
# 4.5    41.0
# 4.8    54.0
# 5.1    47.0
# 5.5    60.0
# 5.9    62.0
# 6.1    67.0
# 6.9    76.0
# 7.4    69.0
# 7.7    85.0
# 7.8    86.0
# 8.3    81.0
# 8.5    75.0
# 8.9    95.0
# 9.2    88.0
# Name: Scores, dtype: float64

# %% [markdown]
# #EXPLORING THE DATA

# %%
plt.figure(figsize=(20,10))
ax1=plt.subplot(1,2,1)
plt.plot(df['Scores'])
plt.title('Scores of students',fontsize=25)
ax2=plt.subplot(1,2,2)
plt.plot(df['Hours'])
plt.title('No. of hours spent', fontsize=25)
# Out:
# Text(0.5, 1.0, 'No. of hours spent')

# %%
plt.scatter(df['Hours'], df['Scores'], color='pink',marker='o')
plt.title("Hours Vs Scores")
plt.xlabel("Hours studied")
plt.ylabel("Percentage Scoreed")
plt.show()

# %%
df.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['Hours'].plot(kind='hist', bins=20, title='Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Scores'].plot(kind='hist', bins=20, title='Scores')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12.plot(kind='scatter', x='Hours', y='Scores', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Scores']
#   ys = series['Hours']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('Scores', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Scores')
# _ = plt.ylabel('Hours')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Scores']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Scores'}, axis=1)
#               .sort_values('Scores', ascending=True))
#   xs = counted['Scores']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('Scores', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Scores')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['Hours'].plot(kind='line', figsize=(8, 4), title='Hours')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Scores'].plot(kind='line', figsize=(8, 4), title='Scores')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
sns.lmplot(x="Hours",y="Scores", data=df)
plt.title("Plotting the regression line")
# Out:
# Text(0.5, 1.0, 'Plotting the regression line')

# %% [markdown]
# #division of data

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
X
# Out:
# array([[2.5],
#        [5.1],
#        [3.2],
#        [8.5],
#        [3.5],
#        [1.5],
#        [9.2],
#        [5.5],
#        [8.3],
#        [2.7],
#        [7.7],
#        [5.9],
#        [4.5],
#        [3.3],
#        [1.1],
#        [8.9],
#        [2.5],
#        [1.9],
#        [6.1],
#        [7.4],
#        [2.7],
#        [4.8],
#        [3.8],
#        [6.9],
#        [7.8]])

# %%
y
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86])

# %% [markdown]
# #TRAINING THE DATA

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([17.04289179, 33.51695377, 74.21757747, 26.73351648, 59.68164043,
#        39.33132858, 20.91914167, 78.09382734, 69.37226512])

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1
# Out:
#    Actual  Predicted
# 0      20  17.042892
# 1      27  33.516954
# 2      69  74.217577
# 3      30  26.733516
# 4      62  59.681640
# 5      35  39.331329
# 6      24  20.919142
# 7      86  78.093827
# 8      76  69.372265
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['Actual'].plot(kind='hist', bins=20, title='Actual')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1['Predicted'].plot(kind='hist', bins=20, title='Predicted')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1.plot(kind='scatter', x='Actual', y='Predicted', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['Actual'].plot(kind='line', figsize=(8, 4), title='Actual')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df1['Predicted'].plot(kind='line', figsize=(8, 4), title='Predicted')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# #VISUALISE THE DATA

# %%
plt.scatter(X_train,y_train, color='violet')
plt.plot(X_train,regressor.predict(X_train),color='orange')
plt.title('(Trainig set)')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'green')
plt.plot(X_train, regressor.predict(X_train), color = 'brown')
plt.title('(Testing set)')
plt.xlabel('Hours studied')
plt.ylabel('Percentage Scored')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap="YlOrBr",annot_kws={'fontsize':12})
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.scatter(y_test,y_pred,c='b')
plt.plot(y_test,y_pred,c='y')
plt.xlabel("Prices")
plt.ylabel("Predicted Score")
plt.title("Score vs Predicted Score")
plt.show()

# %% [markdown]
# #Prediction score if student studies 9.25 hours per day

# %%
Hours = np.array([[9.25]])
predict=regressor.predict(Hours)
print("No of Hours = {}".format(Hours))
print("Predicted Score = {}".format(predict[0]))
print("Train : ",regressor.score(X_train,y_train)*100)
print("Test : ",regressor.score(X_test,y_test)*100)
# Out:
# No of Hours = [[9.25]]
# Predicted Score = 92.14523314523316
# Train :  95.01107277744313
# Test :  95.55700801388129

# %%
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print('Mean absolute error:', metrics.mean_absolute_error(y_test, regressor.predict(X_test)))
print('r^2 score error:',r2_score(y_test, regressor.predict(X_test)))
print('Mean squared error: ',mean_squared_error(y_test, regressor.predict(X_test)))
# Out:
# Mean absolute error: 4.691397441397446
# r^2 score error: 0.9555700801388128
# Mean squared error:  25.463280738222593
